# %%
import pandas as pd

nba = pd.read_csv("nba.csv")
                  
nba.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.sort_values("Name")
# Out:
#                 Name                    Team  Number Position  Age  Height  \
# 152     Aaron Brooks           Chicago Bulls       0       PG   31     6-0
# 356     Aaron Gordon           Orlando Magic       0       PF   20  06-Sep
# 328   Aaron Harrison       Charlotte Hornets       9       SG   21  06-Jun
# 404    Adreian Payne  Minnesota Timberwolves      33       PF   25  06-Oct
# 312       Al Horford           Atlanta Hawks      15        C   30  06-Oct
# ..               ...                     ...     ...      ...  ...     ...
# 386  Wilson Chandler          Denver Nuggets      21       SF   29  06-Aug
# 270   Xavier Munford       Memphis Grizzlies      14       PG   24  06-Mar
# 402      Zach LaVine  Minnesota Timberwolves       8       PG   21  06-May
# 271    Zach Randolph       Memphis Grizzlies      50       PF   34  06-Sep
# 237    Zaza Pachulia        Dallas Mavericks      27        C   32  06-Nov
#
#      Weight         College      Salary
# ...

# %%
nba.sort_values("Name", ascending=False).head()
# Out:
#                 Name                    Team  Number Position  Age  Height  \
# 237    Zaza Pachulia        Dallas Mavericks      27        C   32  06-Nov
# 271    Zach Randolph       Memphis Grizzlies      50       PF   34  06-Sep
# 402      Zach LaVine  Minnesota Timberwolves       8       PG   21  06-May
# 270   Xavier Munford       Memphis Grizzlies      14       PG   24  06-Mar
# 386  Wilson Chandler          Denver Nuggets      21       SF   29  06-Aug
#
#      Weight         College      Salary
# 237     275             NaN   5200000.0
# 271     260  Michigan State   9638555.0
# 402     189            UCLA   2148360.0
# 270     180    Rhode Island         NaN
# 386     225          DePaul  10449438.0

# %%
nba.sort_values("Age", ascending=False).head()
# Out:
#                Name                    Team  Number Position  Age  Height  \
# 304    Andre Miller       San Antonio Spurs      24       PG   40  06-Mar
# 400   Kevin Garnett  Minnesota Timberwolves      21       PF   40  06-Nov
# 298      Tim Duncan       San Antonio Spurs      21        C   40  06-Nov
# 261    Vince Carter       Memphis Grizzlies      15       SG   39  06-Jun
# 102  Pablo Prigioni    Los Angeles Clippers       9       PG   39  06-Mar
#
#      Weight         College     Salary
# 304     200            Utah   250750.0
# 400     240             NaN  8500000.0
# 298     250     Wake Forest  5250000.0
# 261     220  North Carolina  4088019.0
# 102     185             NaN   947726.0

# %%
nba.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight   College  \
# 452    Trey Lyles  Utah Jazz      41       PF   20  06-Oct     234  Kentucky
# 453  Shelvin Mack  Utah Jazz       8       PG   26  06-Mar     203    Butler
# 454     Raul Neto  Utah Jazz      25       PG   24  06-Jan     179       NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26  07-Mar     256       NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     7-0     231    Kansas
#
#         Salary
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
nba.sort_values("Salary", na_position="last")  # Salary te "NaN" sob gula last e cole jbe not parmanent
# Out:
#                        Name                    Team  Number Position  Age  \
# 32   Thanasis Antetokounmpo         New York Knicks      43       SF   23
# 291         Orlando Johnson    New Orleans Pelicans       0       SG   27
# 130            Phil Pressey            Phoenix Suns      25       PG   25
# 135           Alan Williams            Phoenix Suns      15        C   23
# 175            Jordan McRae     Cleveland Cavaliers      12       SG   25
# ..                      ...                     ...     ...      ...  ...
# 273          Alex Stepheson       Memphis Grizzlies      35       PF   28
# 350           Briante Weber              Miami Heat      12       PG   23
# 353           Dorell Wright              Miami Heat      11       SF   30
# 397            Axel Toupane          Denver Nuggets       6       SG   23
# 409              Greg Smith  Minnesota Timberwolves       4       PF   25
#
#      Height  Weight                College    Salary
# ...

# %%
nba.sort_values("Salary", na_position="first")   # Salary te NaN sob First e cole jbe not parmanent
# Out:
#                 Name                 Team  Number Position  Age  Height  \
# 2       John Holland       Boston Celtics      30       SG   27  06-May
# 46       Elton Brand   Philadelphia 76ers      42       PF   37  06-Sep
# 171    Dahntay Jones  Cleveland Cavaliers      30       SG   35  06-Jun
# 264    Jordan Farmar    Memphis Grizzlies       4       PG   29  06-Feb
# 269     Ray McCallum    Memphis Grizzlies       5       PG   24  06-Mar
# ..               ...                  ...     ...      ...  ...     ...
# 339       Chris Bosh           Miami Heat       1       PF   32  06-Nov
# 251    Dwight Howard      Houston Rockets      12        C   30  06-Nov
# 33   Carmelo Anthony      New York Knicks       7       SF   32  06-Aug
# 169     LeBron James  Cleveland Cavaliers      23       SF   31  06-Aug
# 109      Kobe Bryant   Los Angeles Lakers      24       SF   37  06-Jun
#
#      Weight            College      Salary
# 2       205  Boston University         NaN
# ...
