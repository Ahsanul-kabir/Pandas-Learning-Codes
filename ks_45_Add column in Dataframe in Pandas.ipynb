# %%
import pandas as pd 

nba = pd.read_csv('nba.csv')

nba.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba['Name']
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 452       Trey Lyles
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# Name: Name, Length: 457, dtype: object

# %%
nba.sport   # bcoz sport name kono column nai
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-0d2ade27d28e> in <module>
# ----> 1 nba.sport
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sport'

# %%
nba['Sport'] = 'Cricket'  # Add Column newly

nba.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary    Sport
# 0              Texas  7730337.0  Cricket
# 1          Marquette  6796117.0  Cricket
# 2  Boston University        NaN  Cricket
# 3      Georgia State  1148640.0  Cricket
# 4                NaN  5000000.0  Cricket

# %%
nba['League'] = 'National Cricket Asso.'

nba.head()
# Out:
#             Name            Team  Number    Sport Position  Age  Height  \
# 0  Avery Bradley  Boston Celtics       0  Cricket       PG   25  06-Feb
# 1    Jae Crowder  Boston Celtics      99  Cricket       SF   25  06-Jun
# 2   John Holland  Boston Celtics      30  Cricket       SG   27  06-May
# 3    R.J. Hunter  Boston Celtics      28  Cricket       SG   22  06-May
# 4  Jonas Jerebko  Boston Celtics       8  Cricket       PF   29  06-Oct
#
#    Weight            College     Salary                  League
# 0     180              Texas  7730337.0  National Cricket Asso.
# 1     235          Marquette  6796117.0  National Cricket Asso.
# 2     205  Boston University        NaN  National Cricket Asso.
# 3     185      Georgia State  1148640.0  National Cricket Asso.
# 4     231                NaN  5000000.0  National Cricket Asso.

# %%
nba1 = pd.read_csv('nba.csv')
nba1.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba1.insert(3, column='Sport',value='Basketball')
nba1.head()
# Out:
#             Name            Team  Number       Sport Position  Age  Height  \
# 0  Avery Bradley  Boston Celtics       0  Basketball       PG   25  06-Feb
# 1    Jae Crowder  Boston Celtics      99  Basketball       SF   25  06-Jun
# 2   John Holland  Boston Celtics      30  Basketball       SG   27  06-May
# 3    R.J. Hunter  Boston Celtics      28  Basketball       SG   22  06-May
# 4  Jonas Jerebko  Boston Celtics       8  Basketball       PF   29  06-Oct
#
#    Weight            College     Salary
# 0     180              Texas  7730337.0
# 1     235          Marquette  6796117.0
# 2     205  Boston University        NaN
# 3     185      Georgia State  1148640.0
# 4     231                NaN  5000000.0
