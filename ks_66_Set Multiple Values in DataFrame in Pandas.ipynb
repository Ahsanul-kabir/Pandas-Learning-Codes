# %%
import pandas as pd

bond = pd.read_csv("jamesbond.csv", index_col="Film")
bond.sort_index()

bond.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond["Actor"] == "Sean Connery"
# Out:
# Film
# Dr. No                              True
# From Russia with Love               True
# Goldfinger                          True
# Thunderball                         True
# Casino Royale                      False
# You Only Live Twice                 True
# On Her Majesty's Secret Service    False
# Diamonds Are Forever                True
# Live and Let Die                   False
# The Man with the Golden Gun        False
# The Spy Who Loved Me               False
# Moonraker                          False
# For Your Eyes Only                 False
# Never Say Never Again               True
# Octopussy                          False
# A View to a Kill                   False
# The Living Daylights               False
# Licence to Kill                    False
# GoldenEye                          False
# Tomorrow Never Dies                False
# The World Is Not Enough            False
# Die Another Day                    False
# Casino Royale                      False
# ...

# %%
mask = bond["Actor"] == "Sean Connery"   # Sob gula Sean Connery dekaitese
bond[mask]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# You Only Live Twice                  4.4
# Diamonds Are Forever                 5.8
# ...

# %%
bond[mask]["Actor"]    # Orginal data set e perfrom kortese
# Out:
# Film
# Dr. No                   Sean Connery
# From Russia with Love    Sean Connery
# Goldfinger               Sean Connery
# Thunderball              Sean Connery
# You Only Live Twice      Sean Connery
# Diamonds Are Forever     Sean Connery
# Never Say Never Again    Sean Connery
# Name: Actor, dtype: object

# %%
bond[mask]["Actor"] = "Sir Sean Connery"   # ei problem hoitese ei regular method use korbar jonno..
                                            # eta copy data set not Orginal
                                            # Copy data set e perfrom kortese
# Out:
# C:\Users\Nayeem\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
bond.head()     # Orginal data set e kono cng hoy ni # er aager cell ===>> Copy data set e perfrom kortese tai kono change hoy ni
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
df2 = bond[mask]
df2["Actor"] = "Sir Sean Connery"   # Change hoy ni tai solution eta but copy data set use hoise
df2
# Out:
# C:\Users\Nayeem\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                        Year             Actor        Director  Box Office  \
# Film
# Dr. No                 1962  Sir Sean Connery   Terence Young       448.8
# From Russia with Love  1963  Sir Sean Connery   Terence Young       543.8
# Goldfinger             1964  Sir Sean Connery    Guy Hamilton       820.4
# Thunderball            1965  Sir Sean Connery   Terence Young       848.1
# You Only Live Twice    1967  Sir Sean Connery   Lewis Gilbert       514.2
# Diamonds Are Forever   1971  Sir Sean Connery    Guy Hamilton       442.5
# Never Say Never Again  1983  Sir Sean Connery  Irvin Kershner       380.0
#
# ...

# %%
mask =bond["Actor"] == "Sean Connery"     # Change hoy ni tai solution eta # Change occur in orginal data set

bond.loc[mask]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# You Only Live Twice                  4.4
# Diamonds Are Forever                 5.8
# ...

# %%
mask =bond["Actor"] == "Sean Connery"   # Change hoy ni tai solution eta # Change occur in orginal data set

bond.loc[mask,"Actor"] = "Sir Sean Connery"  # Specific selected item change kora hoise
bond.head()
# Out:
#                        Year             Actor       Director  Box Office  \
# Film
# Dr. No                 1962  Sir Sean Connery  Terence Young       448.8
# From Russia with Love  1963  Sir Sean Connery  Terence Young       543.8
# Goldfinger             1964  Sir Sean Connery   Guy Hamilton       820.4
# Thunderball            1965  Sir Sean Connery  Terence Young       848.1
# Casino Royale          1967       David Niven     Ken Hughes       315.0
#
#                        Budget  Bond Actor Salary
# Film
# Dr. No                    7.0                0.6
# From Russia with Love    12.6                1.6
# Goldfinger               18.6                3.2
# Thunderball              41.9                4.7
# Casino Royale            85.0                NaN

# %% [markdown]
# # Finally kaj kora lage niser command diya ↓

# %%
# bond[bond["Actor"] == "Roger Moore"]
bond.loc[bond["Actor"] == "Roger Moore"]     # Change occur in orginal data set
                                             # Change All item in a Row
# Out:
#                              Year        Actor       Director  Box Office  \
# Film
# Live and Let Die             1973  Roger Moore   Guy Hamilton       460.3
# The Man with the Golden Gun  1974  Roger Moore   Guy Hamilton       334.0
# The Spy Who Loved Me         1977  Roger Moore  Lewis Gilbert       533.0
# Moonraker                    1979  Roger Moore  Lewis Gilbert       535.0
# For Your Eyes Only           1981  Roger Moore      John Glen       449.4
# Octopussy                    1983  Roger Moore      John Glen       373.8
# A View to a Kill             1985  Roger Moore      John Glen       275.2
#
#                              Budget  Bond Actor Salary
# Film
# Live and Let Die               30.8                NaN
# The Man with the Golden Gun    27.7                NaN
# The Spy Who Loved Me           45.1                NaN
# Moonraker                      91.5                NaN
# For Your Eyes Only             60.2                NaN
# ...
